# %% [markdown]
# **Author:** Christopher Millward<br>
# **Date:** June 29, 2026
#
# Some of the new data files seem long... I am going to loop through them and see if any need trimming.
#
# **Basis:** I will plot humeral abduction for each file. If the arm is held in a weird position for a long period of time, I will assume the shirt was taken off, but the sensor wasn't powered down.
#
# Steps (for each file):
# 1. Verify that the axes are defined as expected. (NEED TO DO THIS IN SEPARATE NOTEBOOK... BRB)
# 1. Extract the vertical vector
#
# **Note:** I will need to be able to see at exactly what index the real data ends, so I'll use mlpcursors for functionality.
